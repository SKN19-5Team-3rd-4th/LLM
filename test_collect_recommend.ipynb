# %% [markdown]
# ## Collect 테스트
#
# ---

# %% [markdown]
# ## Recommend 테스트
#
# ---

# %%
collected_data = {
    "room": "거실 / 거실의 빈 벽이 너무 심심해서 놓고 싶어",
    "humidity": "건조",
    "preferred_style": "미니멀",
    "preferred_color": "따뜻한 색",
    "has_dog": True,
    "has_cat": False,
    "isAirCond": True,
    "watering_frequency": "주 1회",
    "user_experience": "쉬움"
}
